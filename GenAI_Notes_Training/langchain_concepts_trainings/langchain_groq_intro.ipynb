# %% [markdown]
# #  LangChain with Groq (Free & Super Fast!)
# ### Install → Load API Key → Invoke → Get Output
#
# >  Groq runs open-source models like **LLaMA 3** at blazing speed — completely free!

# %% [markdown]
# ##  Get Your Free Groq API Key (Do this first!)
#
# 1. Go to 👉 **https://console.groq.com**
# 2. Sign up for free
# 3. Click **API Keys** → **Create API Key**
# 4. Copy the key and paste it into a file called `groq_api_key.txt` in the **same folder as this notebook**

# %% [markdown]
# ## 📦 Step 1: Install Required Libraries

# %%
# !pip install langchain
# !pip install langchain-groq
# !pip install groq
# Out:
# ...
#
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 2/2 [langchain-groq]
#
# ...

# %% [markdown]
# ## 🔑 Step 2: Load API Key from .txt File

# %%
# Load the Groq API key from a .txt file
with open("groqapi.txt", "r") as f:
    api_key = f.read().strip()

print(" Groq API Key loaded!")
print(f" Starts with: {api_key[:8]}...")
# Out:
#  Groq API Key loaded!
#  Starts with: gsk_xwtO...

# %% [markdown]
# ## 🤖 Step 3: Initialize the Model using LangChain + Groq
#
# We'll use **LLaMA 3.3 70B** — a powerful open-source model, completely free on Groq!

# %%
from langchain_groq import ChatGroq

# Initialize LLaMA 3 via Groq
llm = ChatGroq(
    model="llama-3.3-70b-versatile",   # Free open-source LLaMA 3 model
    groq_api_key=api_key,
    temperature=0.7
)

print(" LLaMA 3.3 70B ready via LangChain + Groq!")
# Out:
#  LLaMA 3.3 70B ready via LangChain + Groq!

# %% [markdown]
# ## ▶️ Step 4: Invoke the Model and Get Output

# %%
# Simple invoke — send a prompt, get a response
response = llm.invoke("What is LangChain? Explain in 3 simple lines.")

print(" Response from LLaMA 3:")
print("-" * 40)
print(response.content)
# Out:
#  Response from LLaMA 3:
# ----------------------------------------
# LangChain is an open-source framework for building applications with large language models. It provides a set of tools and libraries to simplify the development process of AI-powered projects. LangChain enables developers to create custom interfaces and workflows for interacting with language models like LLaMA, ChatGPT, and others.

# %% [markdown]
# ## 📝 Step 5: Try More Prompts

# %%
response2 = llm.invoke("Write a one-liner joke about Python programming.")
print(response2.content)
# Out:
# Why did the Python script go to therapy: because it had a lot of 'indent'ed issues to work through.

# %%
response3 = llm.invoke("Explain what an LLM is to a 10-year-old.")
print(response3.content)
# Out:
# Imagine you have a super smart robot friend who can understand and talk to you in a really natural way. This robot friend is called a Large Language Model, or LLM for short.
#
# An LLM is like a computer program that's been trained to learn how people talk and write. It's been shown a huge amount of text, like books, articles, and conversations, so it can understand what words mean and how to use them.
#
# When you ask your LLM robot friend a question or tell it something, it uses all the things it's learned to respond in a way that makes sense. It's like having a really smart, magic dictionary that can talk back to you.
#
# For example, if you ask your LLM friend "What's the capital of France?", it can tell you "The capital of France is Paris!" because it's learned that from all the text it's been trained on.
#
# ...

# %% [markdown]
# ## 🧾 Step 6: Inspect the Full Response Object

# %%
response_full = llm.invoke("What is 2 + 2? Answer in one word.")

print(" Full AIMessage object:")
print(response_full)

print("\n Just the text:")
print(response_full.content)

print("\n Metadata (tokens used, model, etc.):")
print(response_full.response_metadata)
# Out:
# 📦 Full AIMessage object:
# content='Four.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 3, 'prompt_tokens': 48, 'total_tokens': 51, 'completion_time': 0.007311095, 'completion_tokens_details': None, 'prompt_time': 0.002208833, 'prompt_tokens_details': None, 'queue_time': 0.053339446, 'total_time': 0.009519928}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019d867e-1377-7bb1-a0b1-9571e00cf90c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 48, 'output_tokens': 3, 'total_tokens': 51}
#
# 📌 Just the text:
# Four.
#
# 📊 Metadata (tokens used, model, etc.):
# ...

# %% [markdown]
# ##  Bonus: Other Free Models Available on Groq
#
# You can swap the model name in Step 3 to try any of these:

# %%
#  Try switching models — just change the model name below!

# Available free models on Groq:
# "llama-3.3-70b-versatile"     ← Best quality (default)
# "llama3-8b-8192"              ← Smaller, faster
# "mixtral-8x7b-32768"          ← Mixtral open-source
# "gemma2-9b-it"                ← Google Gemma 2

llm2 = ChatGroq(
    model="gemma2-9b-it",   # Switching to Gemma 2
    groq_api_key=api_key,
    temperature=0.5
)

response_gemma = llm2.invoke("Tell me a fun fact about space.")
print(" Gemma 2 says:")
print(response_gemma.content)

# %% [markdown]
# ##  Summary
#
# | Step | What We Did |
# |------|-------------|
# | 1 | Installed `langchain` and `langchain-groq` |
# | 2 | Loaded Groq API key from `groq_api_key.txt` |
# | 3 | Initialized `ChatGroq` with free `llama-3.3-70b-versatile` |
# | 4 | Used `.invoke()` to send a prompt and get response |
# | 5 | Explored response object and metadata |
# | Bonus | Tried multiple free models on Groq |
#
# ---
#
# ### ⚡ Why Groq?
# - ✅ 100% Free (generous daily limits)
# - ✅ No quota = 0 issues
# - ✅ Extremely fast (LPU hardware)
# - ✅ Runs powerful open-source models (LLaMA 3, Mixtral, Gemma)
# - ✅ Works from India without restrictions
#
# ### 🔗 Useful Links
# - [Get Free Groq API Key](https://console.groq.com)
# - [Groq Supported Models](https://console.groq.com/docs/models)
# - [LangChain Groq Docs](https://python.langchain.com/docs/integrations/chat/groq/)
