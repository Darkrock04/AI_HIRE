# %% [markdown]
# # **Introduction to LangChain**
# ## **What's Covered?**
# ## **What is LangChain?**
# ## **Why is LangChain powerful?**

# %% [markdown]
# ## **Key Components of LangChain**
# ### **1. Models (I/O)**
# ### **2. Prompts (Templates)**
# ### **3. Chains & LCEL**
# ### **4. Memory**
# ### **5. Retrieval (RAG)**
