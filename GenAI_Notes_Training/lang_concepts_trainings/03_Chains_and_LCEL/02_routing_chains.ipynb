# %%
from langchain_core.runnables import RunnableBranch

def run_routing_chain(query: str, is_math_question: bool):
    # Conceptual Routing Example
    branch = RunnableBranch(
        (lambda x: is_math_question, math_chain),
        general_chain
    )
    return branch.invoke({"query": query})
