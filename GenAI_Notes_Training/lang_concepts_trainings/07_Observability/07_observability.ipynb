# %% [markdown]
# ## 01 Langfuse Tracing

# %%
import os

# Tracing in LangChain is usually handled via global environment variables.
# Once these are set, all chain.invoke() calls are automatically traced.
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = "ls_YOUR_KEY"

# %% [markdown]
# ## 02 Streaming Callbacks

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq

prompt = ChatPromptTemplate.from_template("Write a 3 sentence story about a {animal}")
llm = ChatGroq(model='llama-3.3-70b-versatile')
chain = prompt | llm | StrOutputParser()

# Using .stream() instead of .invoke() yields tokens in real-time
# for chunk in chain.stream({"animal": "fox"}):
#     print(chunk, end="", flush=True)
