# %% [markdown]
# ## 01 Langfuse Tracing

# %%
import os
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate

# 1. Set your Langfuse API Keys (get these from cloud.langfuse.com)
os.environ["LANGFUSE_SECRET_KEY"] = "sk-lf-..."
os.environ["LANGFUSE_PUBLIC_KEY"] = "pk-lf-..."
os.environ["LANGFUSE_HOST"] = "https://cloud.langfuse.com"

# 2. Import the Langfuse Callback Handler
from langfuse.callback import CallbackHandler
langfuse_handler = CallbackHandler()

# 3. Build a standard LCEL chain
llm = ChatGroq(model='llama-3.3-70b-versatile')
prompt = ChatPromptTemplate.from_template("Explain {topic} in one sentence.")
chain = prompt | llm

# 4. Pass the handler into the 'config' dictionary when invoking
# This will automatically trace the exact prompt, token usage, latency, and cost in the Langfuse UI
# response = chain.invoke({"topic": "Quantum Computing"}, config={"callbacks": [langfuse_handler]})
# print(response.content)

# %% [markdown]
# ## 02 Streaming Callbacks

# %%
from langchain_core.output_parsers import StrOutputParser

streaming_chain = prompt | llm | StrOutputParser()

# Langfuse also perfectly traces streaming responses! 
# for chunk in streaming_chain.stream({"topic": "Black Holes"}, config={"callbacks": [langfuse_handler]}):
#     print(chunk, end="", flush=True)
