# %% [markdown]
# # Generative Models: Autoencoders
# Compressing data down to a latent space and reconstructing it.

# %%
import torch.nn as nn

# %%
# 1. Autoencoder Architecture
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        # Encoder compresses a 784 pixel image down to 3 numbers (latent space)
        self.encoder = nn.Sequential(
            nn.Linear(784, 128),
            nn.ReLU(),
            nn.Linear(128, 3)
        )
        # Decoder tries to recreate the 784 pixel image from those 3 numbers
        self.decoder = nn.Sequential(
            nn.Linear(3, 128),
            nn.ReLU(),
            nn.Linear(128, 784),
            nn.Sigmoid()
        )

    def forward(self, x):
        latent = self.encoder(x)
        reconstructed = self.decoder(latent)
        return reconstructed
